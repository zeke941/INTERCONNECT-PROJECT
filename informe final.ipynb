# %% [markdown]
# Hola **Ezequiel**!
#
# Soy **Patricio Requena** 👋. Es un placer ser el revisor de tu proyecto el día de hoy!
#
# Revisaré tu proyecto detenidamente con el objetivo de ayudarte a mejorar y perfeccionar tus habilidades. Durante mi revisión, identificaré áreas donde puedas hacer mejoras en tu código, señalando específicamente qué y cómo podrías ajustar para optimizar el rendimiento y la claridad de tu proyecto. Además, es importante para mí destacar los aspectos que has manejado excepcionalmente bien. Reconocer tus fortalezas te ayudará a entender qué técnicas y métodos están funcionando a tu favor y cómo puedes aplicarlos en futuras tareas.
#
# _**Recuerda que al final de este notebook encontrarás un comentario general de mi parte**_, empecemos!
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, ⚠️ **por favor, no muevas, modifiques o borres mis comentarios** ⚠️:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# # PROYECTO FINAL- INFORME DE SOLUCIÓN

# %% [markdown]
# ## Resumen Ejecutivo
#
# El proyecto Interconnect — Predicción de Cancelación de Clientes (Churn) desarrolló un modelo de machine learning capaz de anticipar qué usuarios tienen alta probabilidad de darse de baja.
# Se integraron y procesaron cuatro fuentes de datos (contratos, personales, internet y telefonía), generando variables clave sobre permanencia, cargos y servicios activos.
# Tras comparar múltiples modelos, el Gradient Boosting Classifier resultó el más robusto, alcanzando un ROC-AUC de 0.979 y un F1-score de 0.92, optimizado para recall ≥ 0.80.
# Las variables más influyentes fueron SeniorCitizen, active_services_count, MonthlyCharges, tenure_months y recency_days.
# El modelo permite a Interconnect detectar clientes en riesgo de cancelación con alta precisión y aplicar estrategias personalizadas de retención, mejorando la rentabilidad y satisfacción del cliente.

# %% [markdown]
# ## 1) ¿Qué pasos del plan se realizaron y cuáles se omitieron?
#
# ## Realizados
#
# ### Preparación de datos:
#
# Integración de contract, personal, internet y phone usando customerID.
#
# Conversión de tipos: TotalCharges a numérico, BeginDate y EndDate a tipo datetime.
#
# Limpieza de nulos y duplicados; verificación de clientes sin servicios activos.
#
# ### Variable objetivo (churn):
#
# 1 si EndDate contiene fecha (cliente cancelado), 0 si está vacío (cliente activo).
#
# Feature Engineering:
#
# ### Variables creadas:
#
# tenure_months: meses de relación del cliente.
#
# recency_days: días desde la finalización del contrato.
#
# charges_per_tenure: gasto medio mensual.
#
# high_monthly_charge: cargos mensuales sobre la mediana.
#
# active_services_count: número de servicios activos (TV, soporte, backup, etc.).
#
# is_fiber, is_dsl: tipo de conexión.
#
# multiple_lines: número de líneas telefónicas.
#
# ### Preprocesamiento:
#
# ColumnTransformer con imputación (median / most_frequent) y OneHotEncoder denso para categorías.
#
# Selección de características:
#
# SelectKBest (Mutual Information, K = 27) y regularización L1 (Lasso).
#
# Permutation Importance sobre el modelo final para interpretación.
#
# ### Modelado:
#
# Logistic Regression (L1), Random Forest (class_weight) y Gradient Boosting.
#
# Balanceo mediante class_weight="balanced".
#
# Ajuste de umbral:
#
# Optimización del umbral buscando recall ≥ 0.80 y máximo F1.
#
# ### Evaluación:
#
# Comparativa de modelos mediante ROC-AUC, precision, recall, F1, y matriz de confusión.
#
# Interpretación de variables relevantes para el negocio.
#
# ### Omitidos (y justificación):
#
# Boruta y SHAP values: se documentaron como mejoras futuras
#
# Exportación de modelos (.joblib): se omitió para mantener el repositorio limpio; los resultados se imprimen en consola.

# %% [markdown]
# ## 2) ¿Qué dificultades se encontraron y como se resolvieron?
#
# ### Fechas con formato inconsistente:
#
# Solución: pd.to_datetime(..., errors="coerce") para tolerar distintos formatos y crear una fecha de referencia (ref_date).
#
# ### Errores por OneHotEncoder disperso:
#
# Solución: usar sparse_output=False o sparse=False según versión de sklearn.
#
# ### Valores de umbral extremos (0 o 1):
#
# Solución: filtrado de umbrales válidos y búsqueda del máximo F1 dentro del rango que cumple el recall objetivo.
#
# ### Longitud desigual en nombres de features:
#
# Solución: función get_all_feature_names() con recorte defensivo para compatibilidad en Permutation Importance.

# %% [markdown]
# ## 3) Pasos clave para resolver la tarea
#
# Definir claramente la variable objetivo churn.
#
# Realizar feature engineering orientado al comportamiento del cliente.
#
# Aplicar un pipeline completo de preprocesamiento + modelado reproducible.
#
# Evaluar y comparar múltiples algoritmos con balanceo de clases.
#
# Ajustar el umbral de decisión para maximizar la retención (recall alto).
#
# Interpretar resultados con Permutation Importance.

# %% [markdown]
# ## 4) Modelo final y nivel calidad
#
# Modelo final: GradientBoostingClassifier
#
# Métricas principales:
#
# ROC-AUC: 0.9793
#
# Umbral óptimo: 0.479
#
# Recall: 0.863
#
# Precisión: 0.9877
#
# F1-score: 0.9211
#
# Exactitud global: 0.9608
#
# Top 5 variables más influyentes (Permutation Importance):
#
# SeniorCitizen — 0.1867
#
# active_services_count — 0.0184
#
# MonthlyCharges — 0.0122
#
# tenure_months — 0.0102
#
# recency_days — 0.0075
#
# ### Interpretación de negocio:
# Los clientes mayores, con mayor gasto mensual y menor tiempo de relación muestran mayor probabilidad de cancelar el servicio.
# En cambio, quienes poseen más servicios contratados suelen mostrar mayor fidelidad.

# %% [markdown]
# ## 5) Conclusión
#
# El modelo final basado en Gradient Boosting alcanzó un desempeño sobresaliente (ROC-AUC ≈ 0.98) y un equilibrio óptimo entre recall y precisión tras ajustar el umbral.
# El pipeline es reproducible, modular y escalable, permitiendo incorporar en el futuro técnicas más avanzadas de selección de características e interpretabilidad (Boruta, SHAP).
# Estos resultados permiten a Interconnect anticipar cancelaciones con alta confianza y diseñar estrategias proactivas de retención de clientes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# ¡Felicidades Ezequiel! Completaste tu proyecto con un informe bastante detallado de los resultados obtenidos y los pasos realizados para llegar hasta ellos.
#
# La redacción de tus pasos y procesos es muy clara, redactaste muy bien los resultados de tu modelo y las métricas utilizadas dejando claro que el entrenamiento y evaluación salieron de manera correcta.
#
# Sin más, sólo me queda decir que la práctica hace al maestro, te invito a seguir profundizando en más tecnicas de machine learning y también a como llevar estos modelos a un entorno productivo donde pueda dar más valor a la empresa para la cual se lo plantee. Recuerda que los proyectos de datos siempre deben ir de la mano con los objetivos de la empresa, siempre deben buscar el beneficio de la misma por lo que es clave que primero se entienda el funcionamiento del negocio antes de pasar a cualquier proyecto.
#
# Saludos!
# </div>
